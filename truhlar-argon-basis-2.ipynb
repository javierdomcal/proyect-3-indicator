# %% [markdown]
# # Comparison between my code and bibliography: The Journal of Physical Chemistry A
# ## Vol 123 / Issue 38
# ### On-Top Ratio for Atoms and Molecules
#
# **Article Subscribed: August 22, 2019**
# *Authors: Rebecca K. Carlson, Donald G. Truhlar, Laura Gagliardi*

# %%
# Imports
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
sys.path.append("src")

from file_management import FileManager
from cluster_connection import ClusterConnection
from job_manager import JobManager
from slurm_manager import SlurmManager
from flux_correlation_indicator import FluxCorrelationIndicator
from molecule import Molecule
from basis import BasisSet
from method import Method
from input_specification import InputSpecification

# %%
# First cell - Import necessary libraries
import concurrent.futures
import logging
import re
from IPython.display import display, HTML

# Set up logging with IPython display
class IPythonLogger(logging.Handler):
    def emit(self, record):
        msg = self.format(record)
        color = {
            logging.ERROR: 'red',
            logging.WARNING: 'orange',
            logging.INFO: 'blue',
            logging.DEBUG: 'grey'
        }.get(record.levelno, 'black')
        
        display(HTML(f'<div style="color: {color};">{msg}</div>'))

# Configure logger
logger = logging.getLogger('CalcLogger')
logger.setLevel(logging.INFO)
logger.addHandler(IPythonLogger())

# %%
# Second cell - Helper functions
def parse_method_name(method_name):
    """Parse method name to extract components."""
    match = re.search(r'\(([^,]+),\s*([^)]+)\)', method_name)
    if not match:
        raise ValueError(f"Invalid method name format: {method_name}")
    return match.group(1).strip(), match.group(2).strip()

def generate_job_name(molecule_name, method_parts, basis_name):
    """Generate standardized job name."""
    return f"{molecule_name[:2]}{method_parts[0]}{method_parts[1]}{basis_name.replace('-', '').replace('*','p')}"

# %%
def process_single_calculation(params, config_file="utils/cluster_config.json"):
    """Process a single calculation."""
    try:
        params['status'] = 'running'
        molecule = Molecule(name=params['molecule_name'])
        method = Method(params['method_name'])
        basis = BasisSet(params['basis_name'])
        
        with ClusterConnection(config_file=config_file) as connection:
            file_manager = FileManager(connection)
            job_manager = JobManager(connection, file_manager, SlurmManager())
            flux_manager = FluxCorrelationIndicator(connection, file_manager, job_manager)
            
            logger.info(f"Starting calculation for job: {params['job_name']}")
            flux_manager.handle_flux(params['job_name'], molecule, method, basis)
            result = file_manager.get_results(params['job_name'])
            
            params['status'] = 'completed'
            logger.info(f"Completed calculation for job: {params['job_name']}")
            return result
    except Exception as e:
        params['status'] = 'failed'
        logger.error(f"Error processing calculation for {params['job_name']}: {str(e)}")
        return None

# %%
def launch_ontop_calculation_parallel(molecule_name, method_name, basis, max_workers=3):
    """Launch multiple calculations in parallel with status tracking."""
    try:
        method_parts = parse_method_name(method_name)
        
        # Prepare calculation parameters
        calc_params = []
        for basis_name in basis:
            job_name = generate_job_name(molecule_name, method_parts, basis_name)
            calc_params.append({
                'molecule_name': molecule_name,
                'method_name': method_name,
                'basis_name': basis_name,
                'job_name': job_name,
                'status': 'pending'
            })
        
        def update_status_display():
            status_html = f"""
            <div style="margin: 10px 0;">
            <b>Progress: {sum(1 for p in calc_params if p['status'] == 'completed')} / {len(calc_params)} completed</b>
            </div>
            <table style="width:100%; border-collapse: collapse;">
            <tr style="background-color: #f2f2f2;">
                <th style="border: 1px solid #ddd; padding: 8px;">Job Name</th>
                <th style="border: 1px solid #ddd; padding: 8px;">Basis</th>
                <th style="border: 1px solid #ddd; padding: 8px;">Status</th>
            </tr>
            """
            for param in calc_params:
                status_color = {
                    'pending': '#fff',
                    'running': '#fff3cd',
                    'completed': '#d4edda',
                    'failed': '#f8d7da'
                }.get(param['status'], '#fff')
                
                status_html += f"""
                <tr style="background-color: {status_color}">
                    <td style="border: 1px solid #ddd; padding: 8px;">{param['job_name']}</td>
                    <td style="border: 1px solid #ddd; padding: 8px;">{param['basis_name']}</td>
                    <td style="border: 1px solid #ddd; padding: 8px;">{param['status']}</td>
                </tr>
                """
            status_html += "</table>"
            display(HTML(status_html), clear=True)
        
        # Launch calculations in parallel
        results = []
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            future_to_params = {
                executor.submit(process_single_calculation, params): params
                for params in calc_params
            }
            
            for future in concurrent.futures.as_completed(future_to_params):
                params = future_to_params[future]
                try:
                    result = future.result()
                    if result is not None:
                        results.append((params['basis_name'], result))
                    update_status_display()
                except Exception as e:
                    logger.error(f"Calculation failed for {params['job_name']}: {str(e)}")
                
        # Sort results by basis name to maintain order
        results.sort(key=lambda x: basis.index(x[0]))
        return [r[1] for r in results]
    
    except Exception as e:
        logger.error(f"Error in parallel calculation launch: {str(e)}")
        raise

# %%
def launch_ontop_calculation(molecule_name, method_name, basis):
        # Code to define molecule, method, and basis, then execute job and retrieve results
    
    # Placeholder: Move to project root if needed
    # os.chdir("..")  # Uncomment if needed to change directory
    
    # Define molecule, method, basis
    molecule = Molecule(name=molecule_name)  # Example placeholder
    method = Method(method_name)
    import re
    df_list = []
    for basis_name in basis:

        basis = BasisSet(basis_name)

    # Regular expression to match parts between ( and , and between , and )
        match = re.search(r'\(([^,]+),\s*([^)]+)\)', method_name)
        if match:
            part1 = match.group(1).strip()
            part2 = match.group(2).strip()
    
        
        job_name = molecule_name[:2]+part1+part2+basis_name.replace('-','')
    
        
        # Initialize dataframe to None
        df = None
        with ClusterConnection(config_file="utils/cluster_config.json") as connection:
            file_manager = FileManager(connection)
            job_manager = JobManager(connection, file_manager, SlurmManager())
            flux_manager = FluxCorrelationIndicator(connection, file_manager, job_manager)
        
            # Define the job name and execute the flux
            flux_manager.handle_flux(job_name, molecule, method, basis)
            df = file_manager.get_results(job_name)
            df_list.append(df)

    return df_list

# %%
# Function to obtain atomic indicator
def obtain_atomic_indicator(df):
    # Filter data where y and z are approximately 0

    # Convert x and y from Hartree to Ångstroms
    df['x'] = df['x'] * 0.529177
    df['y'] = df['y'] * 0.529177
    
    # Create indicator column
    df['indicator'] = 2 * df['on_top'] / (df['density']) ** 2
    
    # Select relevant columns
    result_df = df[['x', 'y', 'indicator']].dropna(subset=['indicator'])
    return result_df

# %%
def plot_comparison(df_list, limit):
    """
    Displays line plots comparing multiple DataFrames for Ar.
    
    Parameters:
    - df_list (list): List of DataFrames, each containing 'x', 'y', and other columns needed for indicator calculation
    - limit (float): Upper limit for x coordinates to filter the data
    """    
    # Set up the figure
    fig, ax = plt.subplots(figsize=(10, 6))
    fig.suptitle('Line Plot Comparison for Ar', fontsize=16)
    
    # Process each DataFrame and plot
    colors = plt.cm.tab10(np.linspace(0, 1, len(df_list)))  # Different color for each DataFrame
    
    for df, color in zip(df_list, colors):
        # Calculate indicators for current DataFrame
        calculated_indicator = obtain_atomic_indicator(df)
        
        # Filter data for line plot (y ≈ 0)
        line_data = calculated_indicator[
            (calculated_indicator['y'] <= 0.000001) & 
            (calculated_indicator['x'] <= limit)
        ]
        
        # Sort data by x to ensure smooth line
        line_data = line_data.sort_values('x')
        
        # Plot line
        ax.plot(line_data['x'], line_data['indicator'], color=color, 
               label=f'Dataset {df_list.index(df) + 1}')
    
    # Set titles and labels
    ax.set_title('Calculated OTR Line Plots: Ar')
    ax.set_xlabel('z(Å)')
    ax.set_ylabel('R')
    ax.legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Atoms

# %% [markdown]
# ### He

# %% [markdown]
# ### Ne

# %%
# Example usage for Neon CASSCF calculations
molecule_name = "neon"
method_name = "CASSCF(10,10)"
basis_sets = [
    'cc-pVDZ',
    'cc-pVTZ', 
    'cc-pVQZ',
    'cc-pV5Z'
]

try:
    results = launch_ontop_calculation_parallel(
        molecule_name=molecule_name,
        method_name=method_name,
        basis=basis_sets,
        max_workers=6  # You can adjust this based on your cluster's capacity
    )
    
    # Display summary of results
    print(f"\nCompleted {len(results)} calculations successfully")
    
    # Display results for each calculation
    for i, df in enumerate(results):
        print(f"\nResults for {basis_sets[i]} basis:")
        display(df.head())
        
    # Optional: Save results to files
    for i, df in enumerate(results):
        filename = f"neon_CASSCF10-10_{basis_sets[i].replace('-', '_')}_results.csv"
        df.to_csv(filename)
        print(f"Saved results to {filename}")
        
except Exception as e:
    print(f"Error running calculations: {str(e)}")
# Out:
#             <div style="margin: 10px 0;">
#             <b>Progress: 3 / 4 completed</b>
#             </div>
#             <table style="width:100%; border-collapse: collapse;">
#             <tr style="background-color: #f2f2f2;">
#                 <th style="border: 1px solid #ddd; padding: 8px;">Job Name</th>
#                 <th style="border: 1px solid #ddd; padding: 8px;">Basis</th>
#                 <th style="border: 1px solid #ddd; padding: 8px;">Status</th>
#             </tr>
#
#                 <tr style="background-color: #d4edda">
#                     <td style="border: 1px solid #ddd; padding: 8px;">ne1010ccpVDZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">cc-pVDZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">completed</td>
#                 </tr>
#
#                 <tr style="background-color: #d4edda">
#                     <td style="border: 1px solid #ddd; padding: 8px;">ne1010ccpVTZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">cc-pVTZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">completed</td>
#                 </tr>
#
#                 <tr style="background-color: #d4edda">
#                     <td style="border: 1px solid #ddd; padding: 8px;">ne1010ccpVQZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">cc-pVQZ</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">completed</td>
#                 </tr>
#
#                 <tr style="background-color: #fff3cd">
#                     <td style="border: 1px solid #ddd; padding: 8px;">ne1010ccpV5Z</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">cc-pV5Z</td>
#                     <td style="border: 1px solid #ddd; padding: 8px;">running</td>
#                 </tr>
#                 </table>
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:13:19      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:14:20      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:15:20      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:16:20      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:17:20      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:18:21      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:19:21      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:20:22      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:21:23      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:22:23      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:23:23      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:24:25      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:25:25      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:26:25      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:27:25      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:28:26      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:29:26      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:30:26      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:31:26      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:32:26      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:33:27      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:34:27      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:35:27      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:36:27      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:37:28      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:38:28      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:39:28      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:40:29      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:41:29      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:42:29      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:43:29      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:44:29      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:45:30      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:46:31      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:47:31      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:48:31      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:49:31      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:50:32      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:51:32      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:52:33      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:53:33      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:54:33      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:55:33      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:56:34      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:57:34      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:58:34      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      2:59:34      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:00:35      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:01:35      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:02:35      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:03:35      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:04:36      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:05:36      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:06:36      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:07:36      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:08:37      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:09:37      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:10:38      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:11:39      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:12:39      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:13:39      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:14:39      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:15:40      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:16:40      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:17:40      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:18:41      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:19:41      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:20:41      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:21:41      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:22:42      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:23:42      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:24:42      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:25:42      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:26:43      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:27:45      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:28:45      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:29:45      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:30:45      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:31:46      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:32:46      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:33:46      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:34:46      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:35:47      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:36:47      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:37:48      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:38:49      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:39:49      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:40:49      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:41:50      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:42:50      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:43:50      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:44:50      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:45:51      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:46:51      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:47:52      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:48:52      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:49:52      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:50:53      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:51:53      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:52:53      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:53:53      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:54:54      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:55:54      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:56:54      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:57:56      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:58:56      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      3:59:56      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:00:56      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:01:57      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:02:57      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:03:57      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:04:57      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:05:58      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:06:58      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:07:58      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:08:58      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:09:59      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:10:59      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:11:59      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:12:59      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:14:00      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:15:00      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:16:00      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:17:02      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:18:02      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:19:02      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:20:02      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:21:03      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:22:03      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:23:03      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:24:03      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:25:04      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:26:04      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:27:04      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:28:04      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:29:05      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:30:05      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:31:05      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:32:05      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:33:06      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:34:06      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:35:06      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:36:06      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:37:07      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:38:07      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:39:08      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:40:08      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:41:08      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:42:09      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:43:09      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:44:09      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:45:10      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:46:10      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:47:10      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:48:11      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:49:11      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:50:11      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:51:11      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:52:12      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:53:12      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:54:13      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:55:14      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:56:14      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:57:14      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:58:14      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      4:59:15      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:00:15      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:01:15      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:02:15      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:03:16      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:04:17      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:05:17      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:06:18      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:07:18      1  atlas-364
#
# Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2219774     general     regular     ne1010ccpV5Z_inca       javidom     R      5:08:18      1  atlas-364

# %%
plot_comparison(molecule, obtain_atomic_indicator(df),limit=1.09)

# %% [markdown]
# ### Ar

# %%
molecule = 'argon'
df = launch_ontop_calculation(molecule,'CASSCF(18,18)','dec-pc-4');

# %%
plot_comparison(molecule, obtain_atomic_indicator(df),limit=1.59)

# %%
## Molecules
