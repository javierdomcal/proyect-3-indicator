# %%
from project_3_indicator import run_calculation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
input = {
    'molecule': 'ethene',
    'basis': 'TZVP',
    'method': 'CASSCF(2,2)',
    'properties': ['otr']
}

results = run_calculation(input)
# Out:
# INFO:project_3_indicator.input.specification:Creating input specification for ethene_CASSCF(2,2)_TZVP
# INFO:project_3_indicator.input.specification:Using default basis set 'TZVP'.
# INFO:root:Running GaussianCalculation for CALC_000008
# Connected to atlas.
# Geometry for ethene successfully loaded.
# Method name: CASSCF(2,2) False
# INFO:root:Command output: drwx------ 1 javidom qchem 56 Mar 18 18:22 /dipc/javidom/proyect-3-indicator/CALC_000008
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# Gaussian input file './test/CALC_000008.com' generated successfully.
# INFO:root:Generated Gaussian SLURM script at slurm_scripts/CALC_000008_gaussian.slurm
# Uploaded test/CALC_000008.com to /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008.com on the cluster.
# INFO:root:Input files prepared for CALC_000008
# Uploaded slurm_scripts/CALC_000008_gaussian.slurm to /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008_gaussian.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008.com
#
# INFO:root:Moved CALC_000008.com from colony to scratch for CALC_000008
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008_gaussian.slurm
#
# INFO:root:Moved CALC_000008_gaussian.slurm from colony to scratch for CALC_000008
# INFO:root:Command output: Submitted batch job 2509228
#
# INFO:root:Submitted job with ID 2509228 for CALC_000008_gaussian
# INFO:root:Submitted job 2509228 for CALC_000008_gaussian
# INFO:root:Monitoring job 2509228 for CALC_000008_gaussian...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 32 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509228     general     regular  CALC_000008_gaussian       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509228 for CALC_000008_gaussian still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2509228 for CALC_000008_gaussian completed after 0:24:40.612994
# INFO:root:Job 2509228 completed successfully
# INFO:root:Job 2509228 completed successfully for CALC_000008
# INFO:root:Command output:
# INFO:root:Running DMNCalculation for CALC_000008
# INFO:root:Command output: drwx------ 1 javidom qchem 56 Mar 18 18:22 /dipc/javidom/proyect-3-indicator/CALC_000008
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008.log
#
# INFO:root:Command output:
# here
# INFO:root:Command output:
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008.log
#
# INFO:root:Generated DMN SLURM script at slurm_scripts/CALC_000008_dmn.slurm
# Uploaded slurm_scripts/CALC_000008_dmn.slurm to /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008_dmn.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008_dmn.slurm
#
# INFO:root:Moved CALC_000008_dmn.slurm from colony to scratch for CALC_000008
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008.log
#
# INFO:root:Moved CALC_000008.log from colony to scratch for CALC_000008
# INFO:root:Command output: Submitted batch job 2509244
#
# INFO:root:Submitted job with ID 2509244 for CALC_000008_dmn
# INFO:root:Submitted job 2509244 for CALC_000008_dmn
# INFO:root:Monitoring job 2509244 for CALC_000008_dmn...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509244     general     regular       CALC_000008_dmn       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509244 for CALC_000008_dmn still running, checking again in 32 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2509244 for CALC_000008_dmn completed after 0:01:10.786286
# INFO:root:Job 2509244 completed successfully
# INFO:root:Job 2509244 completed successfully for CALC_000008
# INFO:root:Command output:
# INFO:root:Running DM2PRIMCalculation for CALC_000008
# INFO:root:Command output: drwx------ 1 javidom qchem 57 Mar 26 16:46 /dipc/javidom/proyect-3-indicator/CALC_000008
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/CALC_000008
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/CALC_000008/Test.FChk
#
# INFO:root:Command output:
# INFO:root:Renamed Test.FChk to CALC_000008.fchk
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008.dm2
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008.fchk
#
# INFO:root:Generated DM2PRIM SLURM script at slurm_scripts/CALC_000008_dm2prim.slurm
# Uploaded slurm_scripts/CALC_000008_dm2prim.slurm to /dipc/javidom/proyect-3-indicator/CALC_000008/CALC_000008_dm2prim.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008_dm2prim.slurm
#
# INFO:root:Moved CALC_000008_dm2prim.slurm from colony to scratch for CALC_000008
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008.dm2
#
# INFO:root:Moved CALC_000008.dm2 from colony to scratch for CALC_000008
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/CALC_000008/CALC_000008.fchk
#
# INFO:root:Moved CALC_000008.fchk from colony to scratch for CALC_000008
# INFO:root:Command output: Submitted batch job 2509247
#
# INFO:root:Submitted job with ID 2509247 for CALC_000008_dm2prim
# INFO:root:Submitted job 2509247 for CALC_000008_dm2prim
# INFO:root:Monitoring job 2509247 for CALC_000008_dm2prim...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 32 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (ReqNodeNotAvail, UnavailableNodes:atlas-[164-210,249-293,295-298,301-334,364-366])
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2509247     general     regular   CALC_000008_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2509247 for CALC_000008_dm2prim still running, checking again in 60 seconds
# ERROR:paramiko.transport:Socket exception: Connection reset by peer (104)
# ERROR:root:Error monitoring job 2509247: [Errno 104] Connection reset by peer
# ERROR:root:Error in job submission/monitoring for CALC_000008: [Errno 104] Connection reset by peer
# ERROR:root:Error in job submission/monitoring for CALC_000008: [Errno 104] Connection reset by peer
# ERROR:root:Error in flux CALC_000008: [Errno 104] Connection reset by peer
# ERROR:root:Error in correlation flux for CALC_000008: [Errno 104] Connection reset by peer
# ERROR:root:Error in calculation workflow: [Errno 104] Connection reset by peer
# ERROR:root:Error in calculation execution: [Errno 104] Connection reset by peer
# Disconnected from cluster.
# Exception occurred: <class 'ConnectionResetError'>, [Errno 104] Connection reset by peer
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[4], line 8
#       1 input = {
#       2     'molecule': 'ethene',
#       3     'basis': 'TZVP',
#       4     'method': 'CASSCF(2,2)',
#       5     'properties': ['otr']
#       6 }
# ----> 8 results = run_calculation(input)
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/__init__.py:68, in run_calculation(input)
#      62         else:
#      63             handler = CalculationHandler(
#      64                 connection,
#      65                 file_manager,
#      66                 job_manager
#      67                     )
# ---> 68             results = handler.handle_calculation(input)
#      70         return results
#      72 except Exception as e:
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/handler/calculation.py:80, in CalculationHandler.handle_calculation(self, input)
#      72     screening_handler = ScreeningHandler(
#      73         self.connection,
#      74         self.file_manager,
#      75         self.job_manager
#      76     )
#      77     input_spec = screening_handler.handle_screening(input_spec, input)
# ---> 80 flux_results = self.correlation_flux.handle_correlation_flux(
#      81     calc_id,
#      82     input_spec
#      83 )
#      85 # Store results
#      86 self.store_results(calc_id)
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/flux/correlation.py:39, in CorrelationFlux.handle_correlation_flux(self, job_name, input_spec)
#      35         return self.handle_hf_flux(job_name, input_spec)
#      37     calculations = [self.gaussian, self.dmn, self.dm2prim, self.inca]
# ---> 39     self.handle_flux(
#      40         job_name, input_spec,  calculations
#      41     )
#      42     logging.info(f"Correlation flux completed for {job_name}")
#      45 except Exception as e:
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/flux/flux_manager.py:25, in FluxManager.handle_flux(self, job_name, input_spec, calculations)
#      22         logging.info(f"Running {calc_name} for {job_name}")
#      24         if hasattr(calc, "handle_calculation"):
# ---> 25             calc.handle_calculation(job_name, input_spec)
#      29     return True
#      30 except Exception as e:
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/calculations/base.py:141, in Calculation.handle_calculation(self, job_name, input_spec)
#     138 self._move_required_files_to_scratch(job_name)
#     140 # 4. Submit and monitor job
# --> 141 job_id = self.submit_and_monitor(job_name, step)
#     143 # 5. Retrieve results from scratch
#     144 self.move_all_files_to_colony(job_name)
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/calculations/base.py:66, in Calculation.submit_and_monitor(self, job_name, step)
#      64 """Submit job and monitor until completion."""
#      65 try:
# ---> 66     job_id = self.job_manager.submit_and_monitor(job_name, step)
#      67     logging.info(f"Job {job_id} completed successfully for {job_name}")
#      68     return job_id
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/jobs/manager.py:28, in JobManager.submit_and_monitor(self, job_name, step)
#      25 job_id = self.submitter.submit_job(job_name, step)
#      26 logging.info(f"Submitted job {job_id} for {job_name}_{step}")
# ---> 28 self.monitor.monitor_job(job_id, job_name, step)
#      29 logging.info(f"Job {job_id} completed successfully")
#      31 return job_id
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/jobs/monitoring.py:32, in JobMonitor.monitor_job(self, job_id, job_name, step)
#      29 while True:
#      30     try:
#      31         # Check job status
# ---> 32         output = self.commands.execute_command(f"squeue -j {job_id}")
#      34         # If job not in queue, it's completed
#      35         if job_id not in output:
#
# File ~/Desktop/Doctorado/proyect-3-indicator/src/project_3_indicator/cluster/command.py:26, in ClusterCommands.execute_command(self, command, wait)
#      23 if not self.connection.ssh_client:
#      24     raise ConnectionError("Not connected to cluster.")
# ---> 26 stdin, stdout, stderr = self.connection.ssh_client.exec_command(command)
#      28 if wait:
#      29     stdout.channel.recv_exit_status()
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/client.py:560, in SSHClient.exec_command(self, command, bufsize, timeout, get_pty, environment)
#     520 def exec_command(
#     521     self,
#     522     command,
#    (...)
#     526     environment=None,
#     527 ):
#     528     """
#     529     Execute a command on the SSH server.  A new `.Channel` is opened and
#     530     the requested command is executed.  The command's input and output
#    (...)
#     558         Added the ``get_pty`` kwarg.
#     559     """
# --> 560     chan = self._transport.open_session(timeout=timeout)
#     561     if get_pty:
#     562         chan.get_pty()
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/transport.py:994, in Transport.open_session(self, window_size, max_packet_size, timeout)
#     966 def open_session(
#     967     self, window_size=None, max_packet_size=None, timeout=None
#     968 ):
#     969     """
#     970     Request a new channel to the server, of type ``"session"``.  This is
#     971     just an alias for calling `open_channel` with an argument of
#    (...)
#     992         Added the ``window_size`` and ``max_packet_size`` arguments.
#     993     """
# --> 994     return self.open_channel(
#     995         "session",
#     996         window_size=window_size,
#     997         max_packet_size=max_packet_size,
#     998         timeout=timeout,
#     999     )
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/transport.py:1125, in Transport.open_channel(self, kind, dest_addr, src_addr, window_size, max_packet_size, timeout)
#    1123     if e is None:
#    1124         e = SSHException("Unable to open channel.")
# -> 1125     raise e
#    1126 if event.is_set():
#    1127     break
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/transport.py:2201, in Transport.run(self)
#    2199     self._send_kex_init()
#    2200 try:
# -> 2201     ptype, m = self.packetizer.read_message()
#    2202 except NeedRekeyException:
#    2203     continue
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/packet.py:496, in Packetizer.read_message(self)
#     488 def read_message(self):
#     489     """
#     490     Only one thread should ever be in this function (no other locking is
#     491     done).
#    (...)
#     494     :raises: `.NeedRekeyException` -- if the transport should rekey
#     495     """
# --> 496     header = self.read_all(self.__block_size_in, check_rekey=True)
#     497     if self.__etm_in:
#     498         packet_size = struct.unpack(">I", header[:4])[0]
#
# File ~/Desktop/Doctorado/proyect-3-indicator/venv/lib/python3.9/site-packages/paramiko/packet.py:322, in Packetizer.read_all(self, n, check_rekey)
#     320     raise EOFError()
#     321 try:
# --> 322     x = self.__socket.recv(n)
#     323     if len(x) == 0:
#     324         raise EOFError()
#
# ConnectionResetError: [Errno 104] Connection reset by peer
