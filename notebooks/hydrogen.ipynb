# %%
from project_3_indicator import run_calculation, get_calculation_cube_data
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Error initializing database: no such column: property_id
# Error initializing database: no such column: property_id

# %%
    # Define scanning properties for y and z directions
input = {
    "molecule": "hydrogen",
    "method": "CASSCF(2,2)",
    "basis": 'TZVP',
    "max_workers": 6,
    "grid": {'x':(0,0), 'y':(0,0), 'z':(3,0.05)},
    "properties": ['otr']
}

    # Run calculation for CASSCF(2,2) with scanning properties
results_hyd = run_calculation(input)
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# INFO:paramiko.transport:Authentication (publickey) successful!
# INFO:project_3_indicator.input.specification:Creating input specification for hydrogen with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.input.specification:Using default basis set 'TZVP'.
# INFO:project_3_indicator.handler.calculation:Processing calculation for hydrogen with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.handler.calculation:Created new calculation with ID: 205841
# Connected to atlas.
# Geometry for hydrogen successfully loaded.
# Method name: CASSCF(2,2) False
# otr
# ['density', 'on_top']
# ERROR:root:Error executing command: ls: cannot access /dipc/javidom/proyect-3-indicator/205841: No such file or directory
#
# INFO:root:Command output:
# INFO:root:Created directory: /dipc/javidom/proyect-3-indicator/205841
# INFO:root:Created new colony directory: /dipc/javidom/proyect-3-indicator/205841
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/205841
# Gaussian input file './test/205841.com' generated successfully.
# INFO:root:Generated Gaussian SLURM script at test/205841_gaussian.slurm
# Uploaded test/205841.com to /dipc/javidom/proyect-3-indicator/205841/205841.com on the cluster.
# INFO:root:Input files prepared for 205841
# Uploaded test/205841_gaussian.slurm to /dipc/javidom/proyect-3-indicator/205841/205841_gaussian.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.com
#
# INFO:root:Moved 205841.com from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_gaussian.slurm
#
# INFO:root:Moved 205841_gaussian.slurm from colony to scratch for 205841
# INFO:root:Command output: Submitted batch job 2520409
#
# INFO:root:Submitted job with ID 2520409 for 205841_gaussian
# INFO:root:Submitted job 2520409 for 205841_gaussian
# INFO:root:Monitoring job 2520409 for 205841_gaussian...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520409     general     regular       205841_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520409 for 205841_gaussian still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520409     general     regular       205841_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520409 for 205841_gaussian still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520409     general     regular       205841_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520409 for 205841_gaussian still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520409     general     regular       205841_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520409 for 205841_gaussian still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520409     general     regular       205841_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520409 for 205841_gaussian still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520409 for 205841_gaussian completed after 0:00:32.669306
# INFO:root:Job 2520409 completed successfully
# INFO:root:Job 2520409 completed successfully for 205841
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 8 Apr  7 15:17 /dipc/javidom/proyect-3-indicator/205841
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.log
#
# INFO:root:Command output:
# here
# INFO:root:Command output:
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.log
#
# INFO:root:Generated DMN SLURM script at test/205841_dmn.slurm
# INFO:root:Command output:
# Uploaded test/205841_dmn.slurm to /dipc/javidom/proyect-3-indicator/205841/205841_dmn.slurm on the cluster.
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_dmn.slurm
#
# INFO:root:Moved 205841_dmn.slurm from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.log
#
# INFO:root:Moved 205841.log from colony to scratch for 205841
# INFO:root:Command output: Submitted batch job 2520410
#
# INFO:root:Submitted job with ID 2520410 for 205841_dmn
# INFO:root:Submitted job 2520410 for 205841_dmn
# INFO:root:Monitoring job 2520410 for 205841_dmn...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520410     general     regular            205841_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520410 for 205841_dmn still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520410     general     regular            205841_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520410 for 205841_dmn still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520410     general     regular            205841_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520410 for 205841_dmn still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520410     general     regular            205841_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520410 for 205841_dmn still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520410 for 205841_dmn completed after 0:00:16.521875
# INFO:root:Job 2520410 completed successfully
# INFO:root:Job 2520410 completed successfully for 205841
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 16 Apr  7 15:18 /dipc/javidom/proyect-3-indicator/205841
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/Test.FChk
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841_sd.dm2
#
# INFO:root:Command output:
# INFO:root:Renamed /dipc/javidom/proyect-3-indicator/205841/205841_sd.dm2 to /dipc/javidom/proyect-3-indicator/205841/205841_hfl.dm2
# INFO:root:Command output:
# INFO:root:Renamed Test.FChk to 205841.fchk
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.dm2
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.fchk
#
# INFO:root:Generated DM2PRIM SLURM script at test/205841_dm2prim.slurm
# INFO:root:Command output:
# Uploaded test/205841_dm2prim.slurm to /dipc/javidom/proyect-3-indicator/205841/205841_dm2prim.slurm on the cluster.
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_dm2prim.slurm
#
# INFO:root:Moved 205841_dm2prim.slurm from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.dm2
#
# INFO:root:Moved 205841.dm2 from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.fchk
#
# INFO:root:Moved 205841.fchk from colony to scratch for 205841
# INFO:root:Command output: Submitted batch job 2520411
#
# INFO:root:Submitted job with ID 2520411 for 205841_dm2prim
# INFO:root:Submitted job 2520411 for 205841_dm2prim
# INFO:root:Monitoring job 2520411 for 205841_dm2prim...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520411     general     regular        205841_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520411 for 205841_dm2prim still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520411     general     regular        205841_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520411 for 205841_dm2prim still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520411     general     regular        205841_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520411 for 205841_dm2prim still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520411     general     regular        205841_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520411 for 205841_dm2prim still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520411     general     regular        205841_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520411 for 205841_dm2prim still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520411 for 205841_dm2prim completed after 0:00:33.753647
# INFO:root:Job 2520411 completed successfully
# INFO:root:Job 2520411 completed successfully for 205841
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 30 Apr  7 15:18 /dipc/javidom/proyect-3-indicator/205841
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/205841
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/205841
# INCA input file './test/205841.inp' generated successfully.
# INFO:root:Generated INCA SLURM script at test/205841_inca.slurm
# Uploaded test/205841.inp to /dipc/javidom/proyect-3-indicator/205841/205841.inp on the cluster.
# Uploaded test/205841_inca.slurm to /dipc/javidom/proyect-3-indicator/205841/205841_inca.slurm on the cluster.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.wfx
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.dm2p
#
# INFO:root:Input files prepared for INCA calculation of 205841
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.dm2p
#
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_inca.slurm
#
# INFO:root:Moved 205841_inca.slurm from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.inp
#
# INFO:root:Moved 205841.inp from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.wfx
#
# INFO:root:Moved 205841.wfx from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_hf.dm2
#
# INFO:root:Moved 205841_hf.dm2 from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841_hfl.dm2
#
# INFO:root:Moved 205841_hfl.dm2 from colony to scratch for 205841
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/205841/205841.dm2p
#
# INFO:root:Moved 205841.dm2p from colony to scratch for 205841
# INFO:root:Command output: Submitted batch job 2520412
#
# INFO:root:Submitted job with ID 2520412 for 205841_inca
# INFO:root:Submitted job 2520412 for 205841_inca
# INFO:root:Monitoring job 2520412 for 205841_inca...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520412     general     regular           205841_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520412 for 205841_inca still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520412     general     regular           205841_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520412 for 205841_inca still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520412     general     regular           205841_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520412 for 205841_inca still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520412     general     regular           205841_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520412 for 205841_inca still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520412     general     regular           205841_inca       javidom     R         0:02      1  atlas-274
#
# INFO:root:Job 2520412 for 205841_inca still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520412 for 205841_inca completed after 0:00:34.413689
# INFO:root:Job 2520412 completed successfully
# INFO:root:Job 2520412 completed successfully for 205841
# INFO:root:Command output:
# INFO:root:Correlation flux completed for 205841
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/205841.log
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/205841/205841.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/205841.log
# Downloaded /dipc/javidom/proyect-3-indicator/205841/205841.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/205841.log locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/density.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/205841/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/density.cube
# Downloaded /dipc/javidom/proyect-3-indicator/205841/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/density.cube locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/205841/on_top.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/205841/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/on_top.cube
# INFO:project_3_indicator.handler.calculation:Successfully processed 2 cube files for calculation 205841: ['density', 'on_top']
# INFO:project_3_indicator.handler.calculation:Calculation 205841 completed successfully in 140.8s
# INFO:project_3_indicator.handler.calculation:Created combined DataFrame with 121 grid points for calculation 205841
# INFO:project_3_indicator.handler.calculation:Completed calculation workflow for 205841 in 140.9s
# Downloaded /dipc/javidom/proyect-3-indicator/205841/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/205841/on_top.cube locally.
#        x    y     z     value
# 0    0.0  0.0 -3.00  0.001825
# 1    0.0  0.0 -2.95  0.002038
# 2    0.0  0.0 -2.90  0.002275
# 3    0.0  0.0 -2.85  0.002539
# 4    0.0  0.0 -2.80  0.002832
# ..   ...  ...   ...       ...
# 116  0.0  0.0  2.80  0.002832
# 117  0.0  0.0  2.85  0.002539
# 118  0.0  0.0  2.90  0.002275
# 119  0.0  0.0  2.95  0.002038
# 120  0.0  0.0  3.00  0.001825
#
# [121 rows x 4 columns]
#        x    y     z         value
# 0    0.0  0.0 -3.00  9.810312e-07
# 1    0.0  0.0 -2.95  1.196739e-06
# 2    0.0  0.0 -2.90  1.458446e-06
# 3    0.0  0.0 -2.85  1.775960e-06
# 4    0.0  0.0 -2.80  2.161354e-06
# ..   ...  ...   ...           ...
# 116  0.0  0.0  2.80  2.161354e-06
# 117  0.0  0.0  2.85  1.775960e-06
# 118  0.0  0.0  2.90  1.458446e-06
# 119  0.0  0.0  2.95  1.196739e-06
# 120  0.0  0.0  3.00  9.810312e-07
#
# [121 rows x 4 columns]
# {'density':        x    y     z     value
# 0    0.0  0.0 -3.00  0.001825
# 1    0.0  0.0 -2.95  0.002038
# 2    0.0  0.0 -2.90  0.002275
# 3    0.0  0.0 -2.85  0.002539
# 4    0.0  0.0 -2.80  0.002832
# ..   ...  ...   ...       ...
# 116  0.0  0.0  2.80  0.002832
# 117  0.0  0.0  2.85  0.002539
# 118  0.0  0.0  2.90  0.002275
# 119  0.0  0.0  2.95  0.002038
# 120  0.0  0.0  3.00  0.001825
#
# [121 rows x 4 columns], 'on_top':        x    y     z         value
# 0    0.0  0.0 -3.00  9.810312e-07
# 1    0.0  0.0 -2.95  1.196739e-06
# 2    0.0  0.0 -2.90  1.458446e-06
# 3    0.0  0.0 -2.85  1.775960e-06
# 4    0.0  0.0 -2.80  2.161354e-06
# ..   ...  ...   ...           ...
# 116  0.0  0.0  2.80  2.161354e-06
# 117  0.0  0.0  2.85  1.775960e-06
# 118  0.0  0.0  2.90  1.458446e-06
# 119  0.0  0.0  2.95  1.196739e-06
# 120  0.0  0.0  3.00  9.810312e-07
#
# [121 rows x 4 columns]}
# Disconnected from cluster.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plot_z_vs_xr(data_path):
    """
    Plot z-coordinate vs X(r) from either a provided dataframe/path or sample data.

    Parameters:
    -----------
    data_path : str or pandas.DataFrame, optional
        Path to data file (CSV, Excel, etc.) or pandas DataFrame containing 'z' and 'X(r)' columns.
        If None, sample data will be generated.

    Returns:
    --------
    fig : matplotlib.figure.Figure
        The matplotlib figure object
    """
    # Load data from file if provided
    if data_path is not None:
        if isinstance(data_path, pd.DataFrame):
            df = data_path
            df['z'] = df['z']*0.529177249
        elif data_path.endswith('.csv'):
            df = pd.read_csv(data_path)
        elif data_path.endswith(('.xls', '.xlsx')):
            df = pd.read_excel(data_path)
        else:
            raise ValueError("Unsupported file format. Please provide a CSV or Excel file.")


    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 6))

    # Plot X(r) vs z
    ax.plot(df['z'], df['X(r)'], 'o-', color='#077FAE', linewidth=2, markersize=4, label='X(r)')

    # Add reference line at X(r) = 1
    ax.axhline(y=1, color='gray', linestyle='--', alpha=0.7, label='Reference (X(r) = 1)')

    # Customize the plot
    ax.set_xlabel('z coordinate (Å)', fontsize=12)
    ax.set_ylabel('X(r)', fontsize=12)
    ax.set_title('Z Coordinate vs X(r)', fontsize=14, fontweight='bold')
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.legend()

    # Add text explaining the significance of X(r)


    plt.tight_layout()
    plt.show()
    return fig

df = results_hyd['cube_df']
plot_z_vs_xr(df)

# %%
    # Define scanning properties for y and z directions
input = {
    "molecule": "hydrogen_2eq",
    "method": "CASSCF(2,2)",
    "basis": 'TZVP',
    "config": 'SP',
    "max_workers": 6,
    "grid": {'x':(0,0), 'y':(0,0), 'z':(4,0.05)},
    "properties": ['otr']
}

    # Run calculation for CASSCF(2,2) with scanning properties
results_hyd2 = run_calculation(input)
df = results_hyd2['cube_df']
plot_z_vs_xr(df)
# Out:
# INFO:project_3_indicator.input.specification:Creating input specification for hydrogen_2eq with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.input.specification:Using default basis set 'TZVP'.
# INFO:project_3_indicator.handler.calculation:Processing calculation for hydrogen_2eq with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.handler.calculation:Created new calculation with ID: 586240
# Connected to atlas.
# Geometry for hydrogen_2eq successfully loaded.
# Method name: CASSCF(2,2) False
# otr
# ['density', 'on_top']
# ERROR:root:Error executing command: ls: cannot access /dipc/javidom/proyect-3-indicator/586240: No such file or directory
#
# INFO:root:Command output:
# INFO:root:Created directory: /dipc/javidom/proyect-3-indicator/586240
# INFO:root:Created new colony directory: /dipc/javidom/proyect-3-indicator/586240
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/586240
# Gaussian input file './test/586240.com' generated successfully.
# INFO:root:Generated Gaussian SLURM script at test/586240_gaussian.slurm
# Uploaded test/586240.com to /dipc/javidom/proyect-3-indicator/586240/586240.com on the cluster.
# INFO:root:Input files prepared for 586240
# Uploaded test/586240_gaussian.slurm to /dipc/javidom/proyect-3-indicator/586240/586240_gaussian.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.com
#
# INFO:root:Moved 586240.com from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_gaussian.slurm
#
# INFO:root:Moved 586240_gaussian.slurm from colony to scratch for 586240
# INFO:root:Command output: Submitted batch job 2520413
#
# INFO:root:Submitted job with ID 2520413 for 586240_gaussian
# INFO:root:Submitted job 2520413 for 586240_gaussian
# INFO:root:Monitoring job 2520413 for 586240_gaussian...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520413     general     regular       586240_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520413 for 586240_gaussian still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520413     general     regular       586240_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520413 for 586240_gaussian still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520413     general     regular       586240_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520413 for 586240_gaussian still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520413     general     regular       586240_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520413 for 586240_gaussian still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520413 for 586240_gaussian completed after 0:00:17.065507
# INFO:root:Job 2520413 completed successfully
# INFO:root:Job 2520413 completed successfully for 586240
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 8 Apr  7 15:22 /dipc/javidom/proyect-3-indicator/586240
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.log
#
# INFO:root:Command output:
# here
# INFO:root:Command output:
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.log
#
# INFO:root:Generated DMN SLURM script at test/586240_dmn.slurm
# Uploaded test/586240_dmn.slurm to /dipc/javidom/proyect-3-indicator/586240/586240_dmn.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_dmn.slurm
#
# INFO:root:Moved 586240_dmn.slurm from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.log
#
# INFO:root:Moved 586240.log from colony to scratch for 586240
# INFO:root:Command output: Submitted batch job 2520414
#
# INFO:root:Submitted job with ID 2520414 for 586240_dmn
# INFO:root:Submitted job 2520414 for 586240_dmn
# INFO:root:Monitoring job 2520414 for 586240_dmn...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520414     general     regular            586240_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520414 for 586240_dmn still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520414     general     regular            586240_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520414 for 586240_dmn still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520414     general     regular            586240_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520414 for 586240_dmn still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520414     general     regular            586240_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520414 for 586240_dmn still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520414     general     regular            586240_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520414 for 586240_dmn still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520414 for 586240_dmn completed after 0:00:33.296945
# INFO:root:Job 2520414 completed successfully
# INFO:root:Job 2520414 completed successfully for 586240
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 16 Apr  7 15:23 /dipc/javidom/proyect-3-indicator/586240
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/Test.FChk
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240_sd.dm2
#
# INFO:root:Command output:
# INFO:root:Renamed /dipc/javidom/proyect-3-indicator/586240/586240_sd.dm2 to /dipc/javidom/proyect-3-indicator/586240/586240_hfl.dm2
# INFO:root:Command output:
# INFO:root:Renamed Test.FChk to 586240.fchk
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.dm2
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.fchk
#
# INFO:root:Generated DM2PRIM SLURM script at test/586240_dm2prim.slurm
# Uploaded test/586240_dm2prim.slurm to /dipc/javidom/proyect-3-indicator/586240/586240_dm2prim.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_dm2prim.slurm
#
# INFO:root:Moved 586240_dm2prim.slurm from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.dm2
#
# INFO:root:Moved 586240.dm2 from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.fchk
#
# INFO:root:Moved 586240.fchk from colony to scratch for 586240
# INFO:root:Command output: Submitted batch job 2520415
#
# INFO:root:Submitted job with ID 2520415 for 586240_dm2prim
# INFO:root:Submitted job 2520415 for 586240_dm2prim
# INFO:root:Monitoring job 2520415 for 586240_dm2prim...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520415     general     regular        586240_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520415 for 586240_dm2prim still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520415     general     regular        586240_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520415 for 586240_dm2prim still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520415     general     regular        586240_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520415 for 586240_dm2prim still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520415     general     regular        586240_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520415 for 586240_dm2prim still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520415 for 586240_dm2prim completed after 0:00:16.632908
# INFO:root:Job 2520415 completed successfully
# INFO:root:Job 2520415 completed successfully for 586240
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 30 Apr  7 15:23 /dipc/javidom/proyect-3-indicator/586240
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/586240
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/586240
# INCA input file './test/586240.inp' generated successfully.
# INFO:root:Generated INCA SLURM script at test/586240_inca.slurm
# Uploaded test/586240.inp to /dipc/javidom/proyect-3-indicator/586240/586240.inp on the cluster.
# Uploaded test/586240_inca.slurm to /dipc/javidom/proyect-3-indicator/586240/586240_inca.slurm on the cluster.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.wfx
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.dm2p
#
# INFO:root:Input files prepared for INCA calculation of 586240
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.dm2p
#
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_inca.slurm
#
# INFO:root:Moved 586240_inca.slurm from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.inp
#
# INFO:root:Moved 586240.inp from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.wfx
#
# INFO:root:Moved 586240.wfx from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_hf.dm2
#
# INFO:root:Moved 586240_hf.dm2 from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240_hfl.dm2
#
# INFO:root:Moved 586240_hfl.dm2 from colony to scratch for 586240
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/586240/586240.dm2p
#
# INFO:root:Moved 586240.dm2p from colony to scratch for 586240
# INFO:root:Command output: Submitted batch job 2520417
#
# INFO:root:Submitted job with ID 2520417 for 586240_inca
# INFO:root:Submitted job 2520417 for 586240_inca
# INFO:root:Monitoring job 2520417 for 586240_inca...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520417     general     regular           586240_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520417 for 586240_inca still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520417     general     regular           586240_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520417 for 586240_inca still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520417     general     regular           586240_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520417 for 586240_inca still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520417     general     regular           586240_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520417 for 586240_inca still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520417     general     regular           586240_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520417 for 586240_inca still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520417 for 586240_inca completed after 0:00:33.054298
# INFO:root:Job 2520417 completed successfully
# INFO:root:Job 2520417 completed successfully for 586240
# INFO:root:Command output:
# INFO:root:Correlation flux completed for 586240
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/586240.log
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/586240/586240.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/586240.log
# Downloaded /dipc/javidom/proyect-3-indicator/586240/586240.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/586240.log locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/density.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/586240/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/density.cube
# Downloaded /dipc/javidom/proyect-3-indicator/586240/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/density.cube locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/586240/on_top.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/586240/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/on_top.cube
# INFO:project_3_indicator.handler.calculation:Successfully processed 2 cube files for calculation 586240: ['density', 'on_top']
# INFO:project_3_indicator.handler.calculation:Calculation 586240 completed successfully in 128.9s
# INFO:project_3_indicator.handler.calculation:Created combined DataFrame with 161 grid points for calculation 586240
# INFO:project_3_indicator.handler.calculation:Completed calculation workflow for 586240 in 129.0s
# Downloaded /dipc/javidom/proyect-3-indicator/586240/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/586240/on_top.cube locally.
#        x    y     z     value
# 0    0.0  0.0 -4.00  0.001401
# 1    0.0  0.0 -3.95  0.001551
# 2    0.0  0.0 -3.90  0.001716
# 3    0.0  0.0 -3.85  0.001897
# 4    0.0  0.0 -3.80  0.002097
# ..   ...  ...   ...       ...
# 156  0.0  0.0  3.80  0.002097
# 157  0.0  0.0  3.85  0.001897
# 158  0.0  0.0  3.90  0.001716
# 159  0.0  0.0  3.95  0.001551
# 160  0.0  0.0  4.00  0.001401
#
# [161 rows x 4 columns]
#        x    y     z         value
# 0    0.0  0.0 -4.00  2.528735e-07
# 1    0.0  0.0 -3.95  3.024659e-07
# 2    0.0  0.0 -3.90  3.613033e-07
# 3    0.0  0.0 -3.85  4.309875e-07
# 4    0.0  0.0 -3.80  5.133767e-07
# ..   ...  ...   ...           ...
# 156  0.0  0.0  3.80  5.133767e-07
# 157  0.0  0.0  3.85  4.309875e-07
# 158  0.0  0.0  3.90  3.613033e-07
# 159  0.0  0.0  3.95  3.024659e-07
# 160  0.0  0.0  4.00  2.528735e-07
#
# [161 rows x 4 columns]
# {'density':        x    y     z     value
# 0    0.0  0.0 -4.00  0.001401
# 1    0.0  0.0 -3.95  0.001551
# 2    0.0  0.0 -3.90  0.001716
# 3    0.0  0.0 -3.85  0.001897
# 4    0.0  0.0 -3.80  0.002097
# ..   ...  ...   ...       ...
# 156  0.0  0.0  3.80  0.002097
# 157  0.0  0.0  3.85  0.001897
# 158  0.0  0.0  3.90  0.001716
# 159  0.0  0.0  3.95  0.001551
# 160  0.0  0.0  4.00  0.001401
#
# [161 rows x 4 columns], 'on_top':        x    y     z         value
# 0    0.0  0.0 -4.00  2.528735e-07
# 1    0.0  0.0 -3.95  3.024659e-07
# 2    0.0  0.0 -3.90  3.613033e-07
# 3    0.0  0.0 -3.85  4.309875e-07
# 4    0.0  0.0 -3.80  5.133767e-07
# ..   ...  ...   ...           ...
# 156  0.0  0.0  3.80  5.133767e-07
# 157  0.0  0.0  3.85  4.309875e-07
# 158  0.0  0.0  3.90  3.613033e-07
# 159  0.0  0.0  3.95  3.024659e-07
# 160  0.0  0.0  4.00  2.528735e-07
#
# [161 rows x 4 columns]}
# Disconnected from cluster.

# %%
input = {
    "molecule": "hydrogen_5eq",
    "method": "CASSCF(2,2)",
    "basis": 'TZVP',
    "config": 'SP',
    "max_workers": 6,
    "grid": {'x':(0,0), 'y':(0,0), 'z':(4,0.05)},
    "properties": ['otr']
}

    # Run calculation for CASSCF(2,2) with scanning properties
results_hyd2 = run_calculation(input)
df = results_hyd2['cube_df']
plot_z_vs_xr(df)
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# INFO:paramiko.transport:Authentication (publickey) successful!
# INFO:project_3_indicator.input.specification:Creating input specification for hydrogen_5eq with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.input.specification:Using default basis set 'TZVP'.
# INFO:project_3_indicator.handler.calculation:Processing calculation for hydrogen_5eq with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.handler.calculation:Created new calculation with ID: 708308
# Connected to atlas.
# Geometry for hydrogen_5eq successfully loaded.
# Method name: CASSCF(2,2) False
# otr
# ['density', 'on_top']
# ERROR:root:Error executing command: ls: cannot access /dipc/javidom/proyect-3-indicator/708308: No such file or directory
#
# INFO:root:Command output:
# INFO:root:Created directory: /dipc/javidom/proyect-3-indicator/708308
# INFO:root:Created new colony directory: /dipc/javidom/proyect-3-indicator/708308
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/708308
# Gaussian input file './test/708308.com' generated successfully.
# INFO:root:Generated Gaussian SLURM script at test/708308_gaussian.slurm
# Uploaded test/708308.com to /dipc/javidom/proyect-3-indicator/708308/708308.com on the cluster.
# INFO:root:Input files prepared for 708308
# Uploaded test/708308_gaussian.slurm to /dipc/javidom/proyect-3-indicator/708308/708308_gaussian.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.com
#
# INFO:root:Moved 708308.com from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_gaussian.slurm
#
# INFO:root:Moved 708308_gaussian.slurm from colony to scratch for 708308
# INFO:root:Command output: Submitted batch job 2520419
#
# INFO:root:Submitted job with ID 2520419 for 708308_gaussian
# INFO:root:Submitted job 2520419 for 708308_gaussian
# INFO:root:Monitoring job 2520419 for 708308_gaussian...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520419     general     regular       708308_gaussian       javidom     R         0:06      1  atlas-331
#
# INFO:root:Job 2520419 for 708308_gaussian still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520419 for 708308_gaussian completed after 0:00:53.646840
# INFO:root:Job 2520419 completed successfully
# INFO:root:Job 2520419 completed successfully for 708308
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 8 Apr  7 15:26 /dipc/javidom/proyect-3-indicator/708308
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.log
#
# INFO:root:Command output:
# here
# INFO:root:Command output:
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.log
#
# INFO:root:Generated DMN SLURM script at test/708308_dmn.slurm
# Uploaded test/708308_dmn.slurm to /dipc/javidom/proyect-3-indicator/708308/708308_dmn.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_dmn.slurm
#
# INFO:root:Moved 708308_dmn.slurm from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.log
#
# INFO:root:Moved 708308.log from colony to scratch for 708308
# INFO:root:Command output: Submitted batch job 2520420
#
# INFO:root:Submitted job with ID 2520420 for 708308_dmn
# INFO:root:Submitted job 2520420 for 708308_dmn
# INFO:root:Monitoring job 2520420 for 708308_dmn...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520420     general     regular            708308_dmn       javidom     R         0:02      1  atlas-331
#
# INFO:root:Job 2520420 for 708308_dmn still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520420 for 708308_dmn completed after 0:00:03.436383
# INFO:root:Job 2520420 completed successfully
# INFO:root:Job 2520420 completed successfully for 708308
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 16 Apr  7 15:26 /dipc/javidom/proyect-3-indicator/708308
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/Test.FChk
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308_sd.dm2
#
# INFO:root:Command output:
# INFO:root:Renamed /dipc/javidom/proyect-3-indicator/708308/708308_sd.dm2 to /dipc/javidom/proyect-3-indicator/708308/708308_hfl.dm2
# INFO:root:Command output:
# INFO:root:Renamed Test.FChk to 708308.fchk
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.dm2
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.fchk
#
# INFO:root:Generated DM2PRIM SLURM script at test/708308_dm2prim.slurm
# Uploaded test/708308_dm2prim.slurm to /dipc/javidom/proyect-3-indicator/708308/708308_dm2prim.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_dm2prim.slurm
#
# INFO:root:Moved 708308_dm2prim.slurm from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.dm2
#
# INFO:root:Moved 708308.dm2 from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.fchk
#
# INFO:root:Moved 708308.fchk from colony to scratch for 708308
# INFO:root:Command output: Submitted batch job 2520421
#
# INFO:root:Submitted job with ID 2520421 for 708308_dm2prim
# INFO:root:Submitted job 2520421 for 708308_dm2prim
# INFO:root:Monitoring job 2520421 for 708308_dm2prim...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520421     general     regular        708308_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520421 for 708308_dm2prim still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520421     general     regular        708308_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520421 for 708308_dm2prim still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520421     general     regular        708308_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520421 for 708308_dm2prim still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520421     general     regular        708308_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520421 for 708308_dm2prim still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520421     general     regular        708308_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520421 for 708308_dm2prim still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520421 for 708308_dm2prim completed after 0:00:33.131198
# INFO:root:Job 2520421 completed successfully
# INFO:root:Job 2520421 completed successfully for 708308
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 30 Apr  7 15:27 /dipc/javidom/proyect-3-indicator/708308
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/708308
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/708308
# INCA input file './test/708308.inp' generated successfully.
# INFO:root:Generated INCA SLURM script at test/708308_inca.slurm
# Uploaded test/708308.inp to /dipc/javidom/proyect-3-indicator/708308/708308.inp on the cluster.
# Uploaded test/708308_inca.slurm to /dipc/javidom/proyect-3-indicator/708308/708308_inca.slurm on the cluster.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.wfx
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.dm2p
#
# INFO:root:Input files prepared for INCA calculation of 708308
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.dm2p
#
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_inca.slurm
#
# INFO:root:Moved 708308_inca.slurm from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.inp
#
# INFO:root:Moved 708308.inp from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.wfx
#
# INFO:root:Moved 708308.wfx from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_hf.dm2
#
# INFO:root:Moved 708308_hf.dm2 from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308_hfl.dm2
#
# INFO:root:Moved 708308_hfl.dm2 from colony to scratch for 708308
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/708308/708308.dm2p
#
# INFO:root:Moved 708308.dm2p from colony to scratch for 708308
# INFO:root:Command output: Submitted batch job 2520422
#
# INFO:root:Submitted job with ID 2520422 for 708308_inca
# INFO:root:Submitted job 2520422 for 708308_inca
# INFO:root:Monitoring job 2520422 for 708308_inca...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520422     general     regular           708308_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520422 for 708308_inca still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520422     general     regular           708308_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520422 for 708308_inca still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520422     general     regular           708308_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520422 for 708308_inca still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520422     general     regular           708308_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520422 for 708308_inca still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520422     general     regular           708308_inca       javidom     R         0:03      1  atlas-331
#
# INFO:root:Job 2520422 for 708308_inca still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520422 for 708308_inca completed after 0:00:32.876064
# INFO:root:Job 2520422 completed successfully
# INFO:root:Job 2520422 completed successfully for 708308
# INFO:root:Command output:
# INFO:root:Correlation flux completed for 708308
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/708308.log
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/708308/708308.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/708308.log
# Downloaded /dipc/javidom/proyect-3-indicator/708308/708308.log to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/708308.log locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/density.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/708308/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/density.cube
# Downloaded /dipc/javidom/proyect-3-indicator/708308/density.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/density.cube locally.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/708308/on_top.cube
#
# INFO:project_3_indicator.handler.calculation:Downloading /dipc/javidom/proyect-3-indicator/708308/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/on_top.cube
# INFO:project_3_indicator.handler.calculation:Successfully processed 2 cube files for calculation 708308: ['density', 'on_top']
# INFO:project_3_indicator.handler.calculation:Calculation 708308 completed successfully in 153.1s
# INFO:project_3_indicator.handler.calculation:Created combined DataFrame with 161 grid points for calculation 708308
# INFO:project_3_indicator.handler.calculation:Completed calculation workflow for 708308 in 153.2s
# Downloaded /dipc/javidom/proyect-3-indicator/708308/on_top.cube to /home/javi/Desktop/Doctorado/proyect-3-indicator/results/708308/on_top.cube locally.
#        x    y     z     value
# 0    0.0  0.0 -4.00  0.113951
# 1    0.0  0.0 -3.95  0.126081
# 2    0.0  0.0 -3.90  0.139264
# 3    0.0  0.0 -3.85  0.153506
# 4    0.0  0.0 -3.80  0.169031
# ..   ...  ...   ...       ...
# 156  0.0  0.0  3.80  0.169031
# 157  0.0  0.0  3.85  0.153506
# 158  0.0  0.0  3.90  0.139264
# 159  0.0  0.0  3.95  0.126081
# 160  0.0  0.0  4.00  0.113951
#
# [161 rows x 4 columns]
#        x    y     z         value
# 0    0.0  0.0 -4.00  3.020204e-07
# 1    0.0  0.0 -3.95  3.723803e-07
# 2    0.0  0.0 -3.90  4.585288e-07
# 3    0.0  0.0 -3.85  5.633268e-07
# 4    0.0  0.0 -3.80  6.916566e-07
# ..   ...  ...   ...           ...
# 156  0.0  0.0  3.80  6.916566e-07
# 157  0.0  0.0  3.85  5.633268e-07
# 158  0.0  0.0  3.90  4.585288e-07
# 159  0.0  0.0  3.95  3.723803e-07
# 160  0.0  0.0  4.00  3.020204e-07
#
# [161 rows x 4 columns]
# {'density':        x    y     z     value
# 0    0.0  0.0 -4.00  0.113951
# 1    0.0  0.0 -3.95  0.126081
# 2    0.0  0.0 -3.90  0.139264
# 3    0.0  0.0 -3.85  0.153506
# 4    0.0  0.0 -3.80  0.169031
# ..   ...  ...   ...       ...
# 156  0.0  0.0  3.80  0.169031
# 157  0.0  0.0  3.85  0.153506
# 158  0.0  0.0  3.90  0.139264
# 159  0.0  0.0  3.95  0.126081
# 160  0.0  0.0  4.00  0.113951
#
# [161 rows x 4 columns], 'on_top':        x    y     z         value
# 0    0.0  0.0 -4.00  3.020204e-07
# 1    0.0  0.0 -3.95  3.723803e-07
# 2    0.0  0.0 -3.90  4.585288e-07
# 3    0.0  0.0 -3.85  5.633268e-07
# 4    0.0  0.0 -3.80  6.916566e-07
# ..   ...  ...   ...           ...
# 156  0.0  0.0  3.80  6.916566e-07
# 157  0.0  0.0  3.85  5.633268e-07
# 158  0.0  0.0  3.90  4.585288e-07
# 159  0.0  0.0  3.95  3.723803e-07
# 160  0.0  0.0  4.00  3.020204e-07
#
# [161 rows x 4 columns]}
# Disconnected from cluster.

# %%
input = {
    "molecule": "ethene",
    "method": "CASSCF(2,2)",
    "basis": 'TZVP',
    "config": 'Opt',
    "max_workers": 6,
    "grid": {'x':(0,0), 'y':(0,0), 'z':(2,0.05)},
    "properties": ['otr']
}

    # Run calculation for CASSCF(2,2) with scanning properties
results_eth = run_calculation(input)
df = results_eth['cube_df']
plot_z_vs_xr(df)
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# INFO:paramiko.transport:Authentication (publickey) successful!
# INFO:project_3_indicator.input.specification:Creating input specification for ethene with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.input.specification:Using default basis set 'TZVP'.
# INFO:project_3_indicator.handler.calculation:Processing calculation for ethene with CASSCF(2,2)/TZVP
# INFO:project_3_indicator.handler.calculation:Created new calculation with ID: 587088
# Connected to atlas.
# Geometry for ethene successfully loaded.
# Method name: CASSCF(2,2) False
# otr
# ['density', 'on_top']
# ERROR:root:Error executing command: ls: cannot access /dipc/javidom/proyect-3-indicator/587088: No such file or directory
#
# INFO:root:Command output:
# INFO:root:Created directory: /dipc/javidom/proyect-3-indicator/587088
# INFO:root:Created new colony directory: /dipc/javidom/proyect-3-indicator/587088
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/587088
# Gaussian input file './test/587088.com' generated successfully.
# INFO:root:Generated Gaussian SLURM script at test/587088_gaussian.slurm
# Uploaded test/587088.com to /dipc/javidom/proyect-3-indicator/587088/587088.com on the cluster.
# INFO:root:Input files prepared for 587088
# Uploaded test/587088_gaussian.slurm to /dipc/javidom/proyect-3-indicator/587088/587088_gaussian.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.com
#
# INFO:root:Moved 587088.com from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_gaussian.slurm
#
# INFO:root:Moved 587088_gaussian.slurm from colony to scratch for 587088
# INFO:root:Command output: Submitted batch job 2520427
#
# INFO:root:Submitted job with ID 2520427 for 587088_gaussian
# INFO:root:Submitted job 2520427 for 587088_gaussian
# INFO:root:Monitoring job 2520427 for 587088_gaussian...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520427     general     regular       587088_gaussian       javidom     R         0:09      1  atlas-274
#
# INFO:root:Job 2520427 for 587088_gaussian still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520427 for 587088_gaussian completed after 0:00:53.374189
# INFO:root:Job 2520427 completed successfully
# INFO:root:Job 2520427 completed successfully for 587088
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 8 Apr  7 15:44 /dipc/javidom/proyect-3-indicator/587088
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.log
#
# INFO:root:Command output:
# here
# INFO:root:Command output:
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.log
#
# INFO:root:Generated DMN SLURM script at test/587088_dmn.slurm
# Uploaded test/587088_dmn.slurm to /dipc/javidom/proyect-3-indicator/587088/587088_dmn.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_dmn.slurm
#
# INFO:root:Moved 587088_dmn.slurm from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.log
#
# INFO:root:Moved 587088.log from colony to scratch for 587088
# INFO:root:Command output: Submitted batch job 2520428
#
# INFO:root:Submitted job with ID 2520428 for 587088_dmn
# INFO:root:Submitted job 2520428 for 587088_dmn
# INFO:root:Monitoring job 2520428 for 587088_dmn...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520428     general     regular            587088_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520428 for 587088_dmn still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520428     general     regular            587088_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520428 for 587088_dmn still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520428     general     regular            587088_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520428 for 587088_dmn still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520428     general     regular            587088_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520428 for 587088_dmn still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520428     general     regular            587088_dmn       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520428 for 587088_dmn still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520428 for 587088_dmn completed after 0:00:33.064962
# INFO:root:Job 2520428 completed successfully
# INFO:root:Job 2520428 completed successfully for 587088
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 16 Apr  7 15:44 /dipc/javidom/proyect-3-indicator/587088
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/Test.FChk
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088_sd.dm2
#
# INFO:root:Command output:
# INFO:root:Renamed /dipc/javidom/proyect-3-indicator/587088/587088_sd.dm2 to /dipc/javidom/proyect-3-indicator/587088/587088_hfl.dm2
# INFO:root:Command output:
# INFO:root:Renamed Test.FChk to 587088.fchk
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.dm2
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.fchk
#
# INFO:root:Generated DM2PRIM SLURM script at test/587088_dm2prim.slurm
# Uploaded test/587088_dm2prim.slurm to /dipc/javidom/proyect-3-indicator/587088/587088_dm2prim.slurm on the cluster.
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_dm2prim.slurm
#
# INFO:root:Moved 587088_dm2prim.slurm from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.dm2
#
# INFO:root:Moved 587088.dm2 from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.fchk
#
# INFO:root:Moved 587088.fchk from colony to scratch for 587088
# INFO:root:Command output: Submitted batch job 2520429
#
# INFO:root:Submitted job with ID 2520429 for 587088_dm2prim
# INFO:root:Submitted job 2520429 for 587088_dm2prim
# INFO:root:Monitoring job 2520429 for 587088_dm2prim...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520429     general     regular        587088_dm2prim       javidom     R         0:12      1  atlas-316
#
# INFO:root:Job 2520429 for 587088_dm2prim still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#
# INFO:root:Job 2520429 for 587088_dm2prim completed after 0:00:53.564870
# INFO:root:Job 2520429 completed successfully
# INFO:root:Job 2520429 completed successfully for 587088
# INFO:root:Command output:
# INFO:root:Command output: drwx------ 1 javidom qchem 30 Apr  7 15:45 /dipc/javidom/proyect-3-indicator/587088
#
# INFO:root:Command output:
# INFO:root:Created directory: /scratch/javidom/proyect-3-indicator/587088
# INFO:root:Created fresh scratch directory: /scratch/javidom/proyect-3-indicator/587088
# INCA input file './test/587088.inp' generated successfully.
# INFO:root:Generated INCA SLURM script at test/587088_inca.slurm
# Uploaded test/587088.inp to /dipc/javidom/proyect-3-indicator/587088/587088.inp on the cluster.
# Uploaded test/587088_inca.slurm to /dipc/javidom/proyect-3-indicator/587088/587088_inca.slurm on the cluster.
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.wfx
#
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.dm2p
#
# INFO:root:Input files prepared for INCA calculation of 587088
# INFO:root:Command output: /dipc/javidom/proyect-3-indicator/587088/587088.dm2p
#
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_inca.slurm
#
# INFO:root:Moved 587088_inca.slurm from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.inp
#
# INFO:root:Moved 587088.inp from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.wfx
#
# INFO:root:Moved 587088.wfx from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_hf.dm2
#
# INFO:root:Moved 587088_hf.dm2 from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088_hfl.dm2
#
# INFO:root:Moved 587088_hfl.dm2 from colony to scratch for 587088
# INFO:root:Command output:
# INFO:root:Command output: /scratch/javidom/proyect-3-indicator/587088/587088.dm2p
#
# INFO:root:Moved 587088.dm2p from colony to scratch for 587088
# INFO:root:Command output: Submitted batch job 2520430
#
# INFO:root:Submitted job with ID 2520430 for 587088_inca
# INFO:root:Submitted job 2520430 for 587088_inca
# INFO:root:Monitoring job 2520430 for 587088_inca...
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 1 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 2 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 4 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 8 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom    PD         0:00      1  (Priority)
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 16 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         0:09      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         0:30      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         0:50      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         1:11      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         1:31      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         1:51      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
# INFO:root:Command output:                JOBID   PARTITION         QOS                  NAME          USER    ST         TIME  NODES  NODELIST(REASON)
#              2520430     general     regular           587088_inca       javidom     R         2:12      1  atlas-331
#
# INFO:root:Job 2520430 for 587088_inca still running, checking again in 20 seconds
